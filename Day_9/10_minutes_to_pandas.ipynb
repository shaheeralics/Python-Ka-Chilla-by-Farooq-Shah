# %%
import pandas as pd
import  numpy   as  np

# %% [markdown]
# **object    creation**

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20130101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -1.048727 -0.485057  1.161153  1.068645
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734
# 2013-01-04 -0.619331 -0.403973  0.493264 -0.055069
# 2013-01-05  0.125543  0.408364  1.131364  1.038911
# 2013-01-06  0.142824  0.653876 -0.084238  0.779511

# %%
import pandas as pd
import numpy as np

# Create the DataFrame with different data types
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# Display the DataFrame
print(df2)

# View basic information
print(df2.info())

# Show descriptive statistics
print(df2.describe(include='all'))
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       4 non-null      float64
#  1   B       4 non-null      datetime64[s]
#  2   C       4 non-null      float32
#  3   D       4 non-null      int32
#  4   E       4 non-null      category
#  5   F       4 non-null      object
# dtypes: category(1), datetime64[s](1), float32(1), float64(1), int32(1), object(1)
# memory usage: 288.0+ bytes
# None
#           A                    B    C    D     E    F
# count   4.0                    4  4.0  4.0     4    4
# unique  NaN                  NaN  NaN  NaN     2    1
# top     NaN                  NaN  NaN  NaN  test  foo
# freq    NaN                  NaN  NaN  NaN     2    4
# mean    1.0  2013-01-02 00:00:00  1.0  3.0   NaN  NaN
# min     1.0  2013-01-02 00:00:00  1.0  3.0   NaN  NaN
# 25%     1.0  2013-01-02 00:00:00  1.0  3.0   NaN  NaN
# 50%     1.0  2013-01-02 00:00:00  1.0  3.0   NaN  NaN
# 75%     1.0  2013-01-02 00:00:00  1.0  3.0   NaN  NaN
# max     1.0  2013-01-02 00:00:00  1.0  3.0   NaN  NaN
# std     0.0                  NaN  0.0  0.0   NaN  NaN

# %% [markdown]
# **viewing   data**

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
#In [12]: df2.<TAB>  
#df2.A                  df2.bool
#df2.abs                df2.boxplot
#df2.add                df2.C
##df2.align              df2.copy
#df2.all                df2.count
#df2.any                df2.combine
#df2.append             df2.D
#df2.apply              df2.describe
#df2.applymap           df2.diff
#df2.B                  df2.duplicated

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -1.048727 -0.485057  1.161153  1.068645
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734
# 2013-01-04 -0.619331 -0.403973  0.493264 -0.055069
# 2013-01-05  0.125543  0.408364  1.131364  1.038911

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734
# 2013-01-04 -0.619331 -0.403973  0.493264 -0.055069
# 2013-01-05  0.125543  0.408364  1.131364  1.038911
# 2013-01-06  0.142824  0.653876 -0.084238  0.779511

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.to_numpy()
# Out:
# array([[-1.04872696, -0.48505749,  1.16115257,  1.06864549],
#        [-0.15813573,  0.31605815,  0.25801289, -1.20190074],
#        [ 0.07150212,  2.75094755, -0.26564311, -1.10173421],
#        [-0.61933145, -0.40397254,  0.49326368, -0.05506879],
#        [ 0.12554331,  0.40836421,  1.1313644 ,  1.03891122],
#        [ 0.14282381,  0.6538763 , -0.08423769,  0.77951125]])

# %%
df2.dtypes
# Out:
# A          float64
# B    datetime64[s]
# C          float32
# D            int32
# E         category
# F           object
# dtype: object

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.247721  0.540036  0.448985  0.088061
# std    0.486104  1.175633  0.601045  1.043443
# min   -1.048727 -0.485057 -0.265643 -1.201901
# 25%   -0.504033 -0.223965  0.001325 -0.840068
# 50%   -0.043317  0.362211  0.375638  0.362221
# 75%    0.112033  0.592498  0.971839  0.974061
# max    0.142824  2.750948  1.161153  1.068645

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A   -1.048727   -0.158136    0.071502   -0.619331    0.125543    0.142824
# B   -0.485057    0.316058    2.750948   -0.403973    0.408364    0.653876
# C    1.161153    0.258013   -0.265643    0.493264    1.131364   -0.084238
# D    1.068645   -1.201901   -1.101734   -0.055069    1.038911    0.779511

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01  1.068645  1.161153 -0.485057 -1.048727
# 2013-01-02 -1.201901  0.258013  0.316058 -0.158136
# 2013-01-03 -1.101734 -0.265643  2.750948  0.071502
# 2013-01-04 -0.055069  0.493264 -0.403973 -0.619331
# 2013-01-05  1.038911  1.131364  0.408364  0.125543
# 2013-01-06  0.779511 -0.084238  0.653876  0.142824

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2013-01-01 -1.048727 -0.485057  1.161153  1.068645
# 2013-01-04 -0.619331 -0.403973  0.493264 -0.055069
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901
# 2013-01-05  0.125543  0.408364  1.131364  1.038911
# 2013-01-06  0.142824  0.653876 -0.084238  0.779511
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734

# %% [markdown]
# *****get    item*****

# %%
df.A
# Out:
# 2013-01-01   -1.048727
# 2013-01-02   -0.158136
# 2013-01-03    0.071502
# 2013-01-04   -0.619331
# 2013-01-05    0.125543
# 2013-01-06    0.142824
# Freq: D, Name: A, dtype: float64

# %%
df  [0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -1.048727 -0.485057  1.161153  1.068645
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734

# %%
df["20130102":"20130104"]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734
# 2013-01-04 -0.619331 -0.403973  0.493264 -0.055069

# %% [markdown]
# selection   by  labels

# %%
df.loc[dates[0]]
# Out:
# A   -1.048727
# B   -0.485057
# C    1.161153
# D    1.068645
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2013-01-01 -1.048727 -0.485057
# 2013-01-02 -0.158136  0.316058
# 2013-01-03  0.071502  2.750948
# 2013-01-04 -0.619331 -0.403973
# 2013-01-05  0.125543  0.408364
# 2013-01-06  0.142824  0.653876

# %%
df.loc["20130102":"20130104",["A","B"]]
# Out:
#                    A         B
# 2013-01-02 -0.158136  0.316058
# 2013-01-03  0.071502  2.750948
# 2013-01-04 -0.619331 -0.403973

# %%
df.loc[dates[0], "A"]
# Out:
# -1.048726956057578

# %%
#FOR   FAST ACESS
df.at[dates[0],"A"]
# Out:
# -1.048726956057578

# %% [markdown]
# selection   for POSITIONING

# %%
#POSITIONING
df.iloc[3]
# Out:
# A   -0.619331
# B   -0.403973
# C    0.493264
# D   -0.055069
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
#integersliceactssimilartonumpyorpython
# Out:
#                    A         B
# 2013-01-04 -0.619331 -0.403973
# 2013-01-05  0.125543  0.408364

# %%
#integerpositioninglocations
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02 -0.158136  0.258013
# 2013-01-03  0.071502 -0.265643
# 2013-01-05  0.125543  1.131364

# %%
#slicing    row explicitly
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734

# %%
#slicing    colomn  explicitly
df.iloc[:,1:3]
# Out:
#                    B         C
# 2013-01-01 -0.485057  1.161153
# 2013-01-02  0.316058  0.258013
# 2013-01-03  2.750948 -0.265643
# 2013-01-04 -0.403973  0.493264
# 2013-01-05  0.408364  1.131364
# 2013-01-06  0.653876 -0.084238

# %%
#for  getting   a  value    explicitly
df.iloc[1,1]
# Out:
# 0.3160581494732929

# %% [markdown]
# boolien expression

# %%
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734
# 2013-01-05  0.125543  0.408364  1.131364  1.038911
# 2013-01-06  0.142824  0.653876 -0.084238  0.779511

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01       NaN       NaN  1.161153  1.068645
# 2013-01-02       NaN  0.316058  0.258013       NaN
# 2013-01-03  0.071502  2.750948       NaN       NaN
# 2013-01-04       NaN       NaN  0.493264       NaN
# 2013-01-05  0.125543  0.408364  1.131364  1.038911
# 2013-01-06  0.142824  0.653876       NaN  0.779511

# %%
df2 = df.copy()

df2["E"] = ["one", "one", "two", "three", "four", "three"]

df2
# Out:
#                    A         B         C         D      E
# 2013-01-01 -1.048727 -0.485057  1.161153  1.068645    one
# 2013-01-02 -0.158136  0.316058  0.258013 -1.201901    one
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734    two
# 2013-01-04 -0.619331 -0.403973  0.493264 -0.055069  three
# 2013-01-05  0.125543  0.408364  1.131364  1.038911   four
# 2013-01-06  0.142824  0.653876 -0.084238  0.779511  three

# %%
df2[df2["E"].isin(["two", "four"])]
# Out:
#                    A         B         C         D     E
# 2013-01-03  0.071502  2.750948 -0.265643 -1.101734   two
# 2013-01-05  0.125543  0.408364  1.131364  1.038911  four

# %% [markdown]
# SETTINGS

# %%
#setting a new  column  automatically   aligns  the data    by  indexes
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range("20130102", periods=6))

# %%
s1
# Out:
# 2013-01-02    1
# 2013-01-03    2
# 2013-01-04    3
# 2013-01-05    4
# 2013-01-06    5
# 2013-01-07    6
# Freq: D, dtype: int64

# %%
df["F"]=s1

# %%
#SETTINGS   VALUES  BY  LABELS
df.at[dates[0], "A"] = 0

# %%
#SETTING    VALUES  BY  POSITION
df.iat[0, 1] = 0

# %%
#Setting by assigning with a NumPy array:


df.loc[:, "D"] = np.array([5] * len(df))

# %%
df
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000  1.161153  5.0  NaN
# 2013-01-02 -0.158136  0.316058  0.258013  5.0  1.0
# 2013-01-03  0.071502  2.750948 -0.265643  5.0  2.0
# 2013-01-04 -0.619331 -0.403973  0.493264  5.0  3.0
# 2013-01-05  0.125543  0.408364  1.131364  5.0  4.0
# 2013-01-06  0.142824  0.653876 -0.084238  5.0  5.0

# %%
df2 = df.copy()

df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C    D    F
# 2013-01-01  0.000000  0.000000 -1.161153 -5.0  NaN
# 2013-01-02 -0.158136 -0.316058 -0.258013 -5.0 -1.0
# 2013-01-03 -0.071502 -2.750948 -0.265643 -5.0 -2.0
# 2013-01-04 -0.619331 -0.403973 -0.493264 -5.0 -3.0
# 2013-01-05 -0.125543 -0.408364 -1.131364 -5.0 -4.0
# 2013-01-06 -0.142824 -0.653876 -0.084238 -5.0 -5.0

# %% [markdown]
# missing data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ["E"])

df1.loc[dates[0] : dates[1], "E"] = 1

# %%
df1
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  1.161153  5.0  NaN  1.0
# 2013-01-02 -0.158136  0.316058  0.258013  5.0  1.0  1.0
# 2013-01-03  0.071502  2.750948 -0.265643  5.0  2.0  NaN
# 2013-01-04 -0.619331 -0.403973  0.493264  5.0  3.0  NaN

# %%
#drop
df1.dropna(how="any")
# Out:
#                    A         B         C    D    F    E
# 2013-01-02 -0.158136  0.316058  0.258013  5.0  1.0  1.0

# %%
#filling
df1.fillna(value=5)
# Out:
#                    A         B         C    D    F    E
# 2013-01-01  0.000000  0.000000  1.161153  5.0  5.0  1.0
# 2013-01-02 -0.158136  0.316058  0.258013  5.0  1.0  1.0
# 2013-01-03  0.071502  2.750948 -0.265643  5.0  2.0  5.0
# 2013-01-04 -0.619331 -0.403973  0.493264  5.0  3.0  5.0

# %%
#gets   boolean masks   where   values  are nan
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %% [markdown]
# *Stats*
#
# Operations in general exclude missing data.
#
# Calculate the mean value for each column:

# %%
df.mean()
# Out:
# A   -0.072933
# B    0.620879
# C    0.448985
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2013-01-01    1.540288
# 2013-01-02    1.283187
# 2013-01-03    1.911361
# 2013-01-04    1.493992
# 2013-01-05    2.133054
# 2013-01-06    2.142492
# Freq: D, dtype: float64

# %%
 s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)
 df.sub(s, axis="index")
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.928498  1.750948 -1.265643  4.0  1.0
# 2013-01-04 -3.619331 -3.403973 -2.506736  2.0  0.0
# 2013-01-05 -4.874457 -4.591636 -3.868636  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
#user   defined functions
df.agg(lambda x: np.mean(x) * 5.6)
# Out:
# A    -0.408425
# B     3.476922
# C     2.514319
# D    28.000000
# F    16.800000
# dtype: float64

# %%
#user   defined function
df.transform(lambda x: x * 101.2)
# Out:
#                     A           B           C      D      F
# 2013-01-01   0.000000    0.000000  117.508640  506.0    NaN
# 2013-01-02 -16.003336   31.985085   26.110904  506.0  101.2
# 2013-01-03   7.236014  278.395892  -26.883083  506.0  202.4
# 2013-01-04 -62.676343  -40.882021   49.918284  506.0  303.6
# 2013-01-05  12.704983   41.326458  114.494077  506.0  404.8
# 2013-01-06  14.453770   66.172282   -8.524854  506.0  506.0

# %%
#valuecounting
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    4
# 1    4
# 2    6
# 3    6
# 4    5
# 5    4
# 6    4
# 7    2
# 8    3
# 9    4
# dtype: int64

# %%
s.value_counts()
# Out:
# 4    5
# 6    2
# 5    1
# 2    1
# 3    1
# Name: count, dtype: int64

# %%
#string methods
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
#merging
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0  1.201563  0.006886  1.102909  0.995473
# 1  2.315617 -1.637054 -0.285140  1.668610
# 2 -0.283617  1.573121 -0.291881  0.169011
# 3  2.220328  1.928894 -1.566632 -0.523971
# 4  0.196581  0.204465 -0.530301 -0.037540
# 5 -0.204551 -2.310928 -0.045289 -0.457837
# 6  1.410350  1.089937 -0.332390 -0.538826
# 7  0.596435  1.787597  0.184519 -0.357314
# 8  0.421027 -1.442184  0.624116  0.058578
# 9  0.744025  1.223853  0.228514 -1.558713

# %%
#break  into    pieces
pieces = [df[:3], df[3:7], df[7:]]

pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  1.201563  0.006886  1.102909  0.995473
# 1  2.315617 -1.637054 -0.285140  1.668610
# 2 -0.283617  1.573121 -0.291881  0.169011
# 3  2.220328  1.928894 -1.566632 -0.523971
# 4  0.196581  0.204465 -0.530301 -0.037540
# 5 -0.204551 -2.310928 -0.045289 -0.457837
# 6  1.410350  1.089937 -0.332390 -0.538826
# 7  0.596435  1.787597  0.184519 -0.357314
# 8  0.421027 -1.442184  0.624116  0.058578
# 9  0.744025  1.223853  0.228514 -1.558713

# %%
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left,right,on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
#grouping
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
  )

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.872810  0.410149
# 1  bar    one -1.275958  1.476782
# 2  foo    two -1.288382  0.077200
# 3  bar  three -0.875094 -1.212091
# 4  foo    two -0.618425 -0.033059
# 5  bar    two  2.405352  0.636059
# 6  foo    one -1.378983 -1.034388
# 7  foo  three -1.549460 -0.968947

# %%
#Grouping by a column label, selecting column labels, and then applying the 
# DataFrameGroupBy.sum() 
# function to the resulting groups:

df.groupby("A")[["C", "D"]].sum()
# Out:
#            C         D
# A
# bar  0.25430  0.900750
# foo -3.96244 -1.549044

# %%
#Grouping by multiple columns label forms MultiIndex.
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.275958  1.476782
#     three -0.875094 -1.212091
#     two    2.405352  0.636059
# foo one   -0.506173 -0.624238
#     three -1.549460 -0.968947
#     two   -1.906807  0.044141

# %%
#REHAPSING
#STACK
arrays = [
   ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
   ["one", "two", "one", "two", "one", "two", "one", "two"],
]


index = pd.MultiIndex.from_arrays(arrays, names=["first", "second"])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one     1.327794  1.302034
#       two     0.037063  0.890669
# baz   one    -0.158371 -0.033718
#       two    -1.198185 -1.177615

# %%
#The stack() method “compresses” a level in the DataFrame’s columns:

stacked = df2.stack(future_stack=True)

stacked
# Out:
# first  second
# bar    one     A    1.327794
#                B    1.302034
#        two     A    0.037063
#                B    0.890669
# baz    one     A   -0.158371
#                B   -0.033718
#        two     A   -1.198185
#                B   -1.177615
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     1.327794  1.302034
#       two     0.037063  0.890669
# baz   one    -0.158371 -0.033718
#       two    -1.198185 -1.177615

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  1.327794  0.037063
#       B  1.302034  0.890669
# baz   A -0.158371 -1.198185
#       B -0.033718 -1.177615

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  1.327794 -0.158371
#        B  1.302034 -0.033718
# two    A  0.037063 -1.198185
#        B  0.890669 -1.177615

# %% [markdown]
# ***pivot   tables***

# %%
df = pd.DataFrame(
    {
        "A": ["one", "one", "two", "three"] * 3,
        "B": ["A", "B", "C"] * 4,
        "C": ["foo", "foo", "foo", "bar", "bar", "bar"] * 2,
        "D": np.random.randn(12),
        "E": np.random.randn(12),
    }
)

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.795485 -0.088964
# 1     one  B  foo  0.500036 -1.178622
# 2     two  C  foo -0.026664 -0.553570
# 3   three  A  bar -0.931934  0.854722
# 4     one  B  bar  1.108198 -1.078791
# 5     one  C  bar  1.522056  1.117911
# 6     two  A  foo  0.517585  0.812417
# 7   three  B  foo -0.747867 -0.519302
# 8     one  C  foo -0.569391  1.546783
# 9     one  A  bar -0.713823  0.338236
# 10    two  B  bar -0.902526  0.249564
# 11  three  C  bar -0.319211  0.627075

# %%
#pivot_table() pivots a DataFrame specifying the values, index and columns

# %%
pd.pivot_table(df, values="D", index=["A", "B"], columns=["C"])
# Out:
# C             bar       foo
# A     B
# one   A -0.713823  0.795485
#       B  1.108198  0.500036
#       C  1.522056 -0.569391
# three A -0.931934       NaN
#       B       NaN -0.747867
#       C -0.319211       NaN
# two   A       NaN  0.517585
#       B -0.902526       NaN
#       C       NaN -0.026664

# %% [markdown]
# ***time series***

# %%
rng = pd.date_range("1/1/2012", periods=100, freq="s")

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample("5Min").sum()
# Out:
# 2012-01-01    25011
# Freq: 5min, dtype: int64

# %%
#Series.tz_localize() localizes a time series to a time zone:
rng = pd.date_range("3/6/2012 00:00", periods=5, freq="D")

ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06   -0.363548
# 2012-03-07    0.008602
# 2012-03-08    0.387167
# 2012-03-09   -1.051400
# 2012-03-10    0.185207
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

ts_utc
# Out:
# 2012-03-06 00:00:00+00:00   -0.363548
# 2012-03-07 00:00:00+00:00    0.008602
# 2012-03-08 00:00:00+00:00    0.387167
# 2012-03-09 00:00:00+00:00   -1.051400
# 2012-03-10 00:00:00+00:00    0.185207
# Freq: D, dtype: float64

# %%
#Series.tz_convert() converts a timezones aware time series to another time zone:

ts_utc.tz_convert("US/EASTERN")
# Out:
# 2012-03-05 19:00:00-05:00   -0.363548
# 2012-03-06 19:00:00-05:00    0.008602
# 2012-03-07 19:00:00-05:00    0.387167
# 2012-03-08 19:00:00-05:00   -1.051400
# 2012-03-09 19:00:00-05:00    0.185207
# Freq: D, dtype: float64

# %%
#Adding a non-fixed duration (BusinessDay) to a time series:
rng
# Out:
# DatetimeIndex(['2012-03-06', '2012-03-07', '2012-03-08', '2012-03-09',
#                '2012-03-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
rng+pd.offsets.BusinessDay(5)
# Out:
# DatetimeIndex(['2012-03-13', '2012-03-14', '2012-03-15', '2012-03-16',
#                '2012-03-16'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ***CATEGORIALS***

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
#Converting the raw grades to a categorical data type:
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
#Rename the categories to more meaningful names:

new_categories = ["very good", "good", "very bad"]

df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
#Reorder the categories and simultaneously add the missing categories
# (methods under Series.cat() return a new Series by default)
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)


df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
#Sorting is per order in the categories, not lexical order:
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
#Grouping by a categorical column with observed=False also shows empty categories:

df.groupby("grade", observed=False).size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %% [markdown]
# ***ploting***

# %%
import matplotlib.pyplot as plt

plt.close("all")

# %%
 ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

 ts = ts.cumsum()

ts.plot();

# %%
#plot   all coloumns
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)


df = df.cumsum()

plt.figure()

df.plot()

plt.legend(loc='best')

plt.show()

# %% [markdown]
# importing   and exporting   data

# %%
#csv
df = pd.DataFrame(np.random.randint(0, 5, (10, 5)))

df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  2  3  4  1
# 1           1  4  2  3  4  1
# 2           2  4  0  3  1  0
# 3           3  4  4  2  4  3
# 4           4  0  2  0  3  4
# 5           5  2  2  4  2  0
# 6           6  0  4  2  2  4
# 7           7  3  1  3  2  4
# 8           8  1  2  3  1  0
# 9           9  1  2  4  2  1

# %%
#parquet
df.to_parquet("foo.parquet")

# %%
pd.read_parquet("foo.parquet")
# Out:
#    0  1  2  3  4
# 0  3  2  3  4  1
# 1  4  2  3  4  1
# 2  4  0  3  1  0
# 3  4  4  2  4  3
# 4  0  2  0  3  4
# 5  2  2  4  2  0
# 6  0  4  2  2  4
# 7  3  1  3  2  4
# 8  1  2  3  1  0
# 9  1  2  4  2  1

# %%
#excel
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
 pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#    Unnamed: 0  0  1  2  3  4
# 0           0  3  2  3  4  1
# 1           1  4  2  3  4  1
# 2           2  4  0  3  1  0
# 3           3  4  4  2  4  3
# 4           4  0  2  0  3  4
# 5           5  2  2  4  2  0
# 6           6  0  4  2  2  4
# 7           7  3  1  3  2  4
# 8           8  1  2  3  1  0
# 9           9  1  2  4  2  1

# %%
import  seaborn     as  sns
kashti=sns.load_dataset('titanic')

kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
kashti[kashti["age"]<1]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 305         1       1    male  0.92      1      2  151.5500        S   First
# 469         1       3  female  0.75      2      1   19.2583        C   Third
# 644         1       3  female  0.75      2      1   19.2583        C   Third
# 755         1       2    male  0.67      1      1   14.5000        S  Second
# 803         1       3    male  0.42      0      1    8.5167        C   Third
# 831         1       2    male  0.83      1      1   18.7500        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 78   child       False  NaN  Southampton   yes  False
# 305  child       False    C  Southampton   yes  False
# 469  child       False  NaN    Cherbourg   yes  False
# 644  child       False  NaN    Cherbourg   yes  False
# 755  child       False  NaN  Southampton   yes  False
# 803  child       False  NaN    Cherbourg   yes  False
# 831  child       False  NaN  Southampton   yes  False

# %%
kashti[kashti["fare"]<5]
# Out:
#      survived  pclass   sex   age  sibsp  parch    fare embarked   class  who  \
# 179         0       3  male  36.0      0      0  0.0000        S   Third  man
# 263         0       1  male  40.0      0      0  0.0000        S   First  man
# 271         1       3  male  25.0      0      0  0.0000        S   Third  man
# 277         0       2  male   NaN      0      0  0.0000        S  Second  man
# 302         0       3  male  19.0      0      0  0.0000        S   Third  man
# 378         0       3  male  20.0      0      0  4.0125        C   Third  man
# 413         0       2  male   NaN      0      0  0.0000        S  Second  man
# 466         0       2  male   NaN      0      0  0.0000        S  Second  man
# 481         0       2  male   NaN      0      0  0.0000        S  Second  man
# 597         0       3  male  49.0      0      0  0.0000        S   Third  man
# 633         0       1  male   NaN      0      0  0.0000        S   First  man
# 674         0       2  male   NaN      0      0  0.0000        S  Second  man
# 732         0       2  male   NaN      0      0  0.0000        S  Second  man
# 806         0       1  male  39.0      0      0  0.0000        S   First  man
# 815         0       1  male   NaN      0      0  0.0000        S   First  man
# 822         0       1  male  38.0      0      0  0.0000        S   First  man
#
#      adult_male deck  embark_town alive  alone
# 179        True  NaN  Southampton    no   True
# 263        True    B  Southampton    no   True
# 271        True  NaN  Southampton   yes   True
# 277        True  NaN  Southampton    no   True
# 302        True  NaN  Southampton    no   True
# 378        True  NaN    Cherbourg    no   True
# 413        True  NaN  Southampton    no   True
# 466        True  NaN  Southampton    no   True
# 481        True  NaN  Southampton    no   True
# 597        True  NaN  Southampton    no   True
# 633        True  NaN  Southampton    no   True
# 674        True  NaN  Southampton    no   True
# 732        True  NaN  Southampton    no   True
# 806        True    A  Southampton    no   True
# 815        True    B  Southampton    no   True
# 822        True  NaN  Southampton    no   True
